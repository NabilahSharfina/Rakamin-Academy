# %% [markdown]
# ## Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Mengenal Konsep Variabel & Assignment

# %% [markdown]
# ## Data Numeric

# %%
tinggi_badan = 173
tinggi_badan2 = 180
# Shift Enter to Runnning, Running by Sequence.

# Untuk membuat Text menjadi Header seperti "Data Numerik" diatas dapat menambah baris text dan tulis # diawalan, contoh "# Data Numeric" untuk Header diatas.

# %% [markdown]
# berapa isi dari variabel tinggi_badan sekarang?

# %%
tinggi_badan2
# Out:
# 180

# %% [markdown]
# ganti nilai tinggi_badan dengan 170

# %%
tinggi_badan = 170

# %% [markdown]
# berapa isi dari variabel tinggi_badan sekarang?

# %%
tinggi_badan
# Out:
# 170

# %%
tinggi_badan/100
#Penggunaan juga bisa menggunakan  + - / *
# Out:
# 1.7

# %%
tinggi_badan_in_m = tinggi_badan/100
tinggi_badan_in_m
# Menggunakan variabel tinggi_badan_in_m untuk menyimpan hasil perhitungan tinggai badan/100
# Out:
# 1.7

# %% [markdown]
# ## Data String

# %%
nama_depan = 'Raffi'
nama_belakang = "Ahmad"

# bebas menggunakan '' petik satu atau "" Petik dua

# %%
nama_depan+nama_belakang
# Out:
# 'RaffiAhmad'

# %%
nama_depan+" "+nama_belakang
# Out:
# 'Raffi Ahmad'

# %%
(nama_depan+" ")*2
# Perkalian
# Out:
# 'Raffi Raffi '

# %% [markdown]
# ## [CHALLENGE] Membuat variabel baru

# %%
#buat variabel nama dan umur di sini
nama = 'TestNamaC'
umur = 22

# %%
"Halo, nama saya "+nama+". Umur saya adalah "+str(umur)+" tahun"
# disini memanggil variabel numerik kedalam text/kalimat harus diconvert menjadi string dengan "str("variabel")"
# Out:
# 'Halo, nama saya TestNamaC. Umur saya adalah 22 tahun'

# %% [markdown]
# # Import Pandas Library

# %%
import pandas as pd
# pd adalah variabel panggilan untuk library pandas, Bisa diganti untuk memudahkan pemanggilan

# %% [markdown]
# # Membaca Dataset

# %% [markdown]
# menggunakan beberapa fungsi sederhana
# 1. .Shape
# 2. .columns
# 3. .head[n]
# 4. .tail[n]

# %%
df_dataset = pd.read_csv('/content/drive/MyDrive/RAKAMIN ACADEMY/FREE CLASS/Trial Class/rakamin_class.csv')
# df_dataset adalah variabel, bisa diganti

# %%
df_dataset
# Out:
#    registration_id    name               email  ...  active  class score
# 0       RK20202344    Nina      nina@gmail.com  ...       1      6    80
# 1       RK20202345    Dyah      dyah@gmail.com  ...       0      2    66
# 2       RK20202346   Prima     prima@ymail.com  ...       1      1    55
# 3       RK20202347  Firman   firman@google.com  ...       1      6    93
# 4       RK20202348     Eva     eva@rakamin.com  ...       0      5    80
# ..             ...     ...                 ...  ...     ...    ...   ...
# 95      RK20202439   Abdul     abdul@gmail.com  ...       0      6    59
# 96      RK20202440     Ria       ria@gmail.com  ...       0      6    58
# 97      RK20202441   Putra     putra@gmail.com  ...       1      6    71
# 98      RK20202442   Kokom  kokom@facebook.com  ...       0      2    73
# 99      RK20202443   Ilham     ilham@gmail.com  ...       1      2    52
#
# [100 rows x 10 columns]

# %% [markdown]
# # Operasi Sederhana Data Frame

# %% [markdown]
# Untuk menggambil data melompat atau data antara baris dan baris menggunakan fungsi index ( Cari Sendiri)
#
# Untuk Find Word juga ada, tapi cari sendiri.

# %% [markdown]
# ## a. shape

# %% [markdown]
# Melihat ukuran Data Frame (baris & kolom)

# %%
df_dataset.shape
# (baris, columns)
# (row, Columns)
# Out:
# (100, 10)

# %%
df_dataset.shape[0]
# Untuk menampilkan banyak row/baris dafa frame. "[0]" menyatakan urutan array dari fungsi shape, 0 adalah row/baris dan 1 adalah column. Karena ini data 2D jadi hanya 2.
# Out:
# 100

# %%
df_dataset.shape[1]
# Out:
# 10

# %% [markdown]
# ## b. columns

# %% [markdown]
# Melihat semua nama kolom

# %%
df_dataset.columns
# Menampilkan nama Columns (Semuanya)
# Out:
# Index(['registration_id', 'name', 'email', 'phone', 'age', 'city', 'province',
#        'active', 'class', 'score'],
#       dtype='object')

# %% [markdown]
# ## c. head()

# %% [markdown]
# Melihat N baris pertama  (default N=5)

# %%
df_dataset.head()
# Default menampilkan 5 baris teratas
# Out:
#   registration_id    name              email  ...  active  class score
# 0      RK20202344    Nina     nina@gmail.com  ...       1      6    80
# 1      RK20202345    Dyah     dyah@gmail.com  ...       0      2    66
# 2      RK20202346   Prima    prima@ymail.com  ...       1      1    55
# 3      RK20202347  Firman  firman@google.com  ...       1      6    93
# 4      RK20202348     Eva    eva@rakamin.com  ...       0      5    80
#
# [5 rows x 10 columns]

# %%
df_dataset.head(3)
# mengubah defaultnya, menampilkan 3 baris teratas
# Out:
#   registration_id   name            email  ...  active  class score
# 0      RK20202344   Nina   nina@gmail.com  ...       1      6    80
# 1      RK20202345   Dyah   dyah@gmail.com  ...       0      2    66
# 2      RK20202346  Prima  prima@ymail.com  ...       1      1    55
#
# [3 rows x 10 columns]

# %% [markdown]
# ## d. tail()

# %% [markdown]
# Melihat N baris terakhir (default N=5)

# %%
df_dataset.tail()
# Default menampilkan 5 baris terbawah
# Out:
#    registration_id   name               email  ...  active  class score
# 95      RK20202439  Abdul     abdul@gmail.com  ...       0      6    59
# 96      RK20202440    Ria       ria@gmail.com  ...       0      6    58
# 97      RK20202441  Putra     putra@gmail.com  ...       1      6    71
# 98      RK20202442  Kokom  kokom@facebook.com  ...       0      2    73
# 99      RK20202443  Ilham     ilham@gmail.com  ...       1      2    52
#
# [5 rows x 10 columns]

# %%
df_dataset.tail(3)
# Default menampilkan 3 baris terbawah
# Out:
#    registration_id   name               email  ...  active  class score
# 97      RK20202441  Putra     putra@gmail.com  ...       1      6    71
# 98      RK20202442  Kokom  kokom@facebook.com  ...       0      2    73
# 99      RK20202443  Ilham     ilham@gmail.com  ...       1      2    52
#
# [3 rows x 10 columns]

# %% [markdown]
# # Data Sorting

# %%
df_dataset.head()
# Out:
#   registration_id    name              email  ...  active  class score
# 0      RK20202344    Nina     nina@gmail.com  ...       1      6    80
# 1      RK20202345    Dyah     dyah@gmail.com  ...       0      2    66
# 2      RK20202346   Prima    prima@ymail.com  ...       1      1    55
# 3      RK20202347  Firman  firman@google.com  ...       1      6    93
# 4      RK20202348     Eva    eva@rakamin.com  ...       0      5    80
#
# [5 rows x 10 columns]

# %% [markdown]
# ### Mengurutkan age dari termuda ke tertua (ASCENDING - Kecil ke besar)

# %%
df_dataset.sort_values('age')
# short value dari column age yang ada di variabel (default dari kecil ke besar)
# Out:
#    registration_id     name                email  ...  active  class score
# 92      RK20202436  Munaroh  munaroh@hotmail.com  ...       0      1    91
# 82      RK20202426      Een     een@facebook.com  ...       1      1    74
# 2       RK20202346    Prima      prima@ymail.com  ...       1      1    55
# 5       RK20202349    Bagus    bagus@hotmail.com  ...       1      1    84
# 7       RK20202351     Yuni      yuni@google.com  ...       0      1    87
# ..             ...      ...                  ...  ...     ...    ...   ...
# 0       RK20202344     Nina       nina@gmail.com  ...       1      6    80
# 42      RK20202386   Hendra   hendra@hotmail.com  ...       1      6    75
# 32      RK20202376   Hafizh    hafizh@google.com  ...       1      6    82
# 3       RK20202347   Firman    firman@google.com  ...       1      6    93
# 13      RK20202357   Amelia     amelia@ymail.com  ...       1      6    67
#
# [100 rows x 10 columns]

# %%
df_dataset.sort_values('age', ascending=True)
# ascending itu dari kecil ke besar, kalau kebalikan ganti jadi false
# Out:
#    registration_id     name                email  ...  active  class score
# 92      RK20202436  Munaroh  munaroh@hotmail.com  ...       0      1    91
# 82      RK20202426      Een     een@facebook.com  ...       1      1    74
# 2       RK20202346    Prima      prima@ymail.com  ...       1      1    55
# 5       RK20202349    Bagus    bagus@hotmail.com  ...       1      1    84
# 7       RK20202351     Yuni      yuni@google.com  ...       0      1    87
# ..             ...      ...                  ...  ...     ...    ...   ...
# 0       RK20202344     Nina       nina@gmail.com  ...       1      6    80
# 42      RK20202386   Hendra   hendra@hotmail.com  ...       1      6    75
# 32      RK20202376   Hafizh    hafizh@google.com  ...       1      6    82
# 3       RK20202347   Firman    firman@google.com  ...       1      6    93
# 13      RK20202357   Amelia     amelia@ymail.com  ...       1      6    67
#
# [100 rows x 10 columns]

# %% [markdown]
# ### Mengurutkan age dari tertua ke termuda (DESCENDING - Besar ke Kecil)

# %%
df_dataset.sort_values('age', ascending=False)
# Out:
#    registration_id     name                email  ...  active  class score
# 13      RK20202357   Amelia     amelia@ymail.com  ...       1      6    67
# 3       RK20202347   Firman    firman@google.com  ...       1      6    93
# 42      RK20202386   Hendra   hendra@hotmail.com  ...       1      6    75
# 32      RK20202376   Hafizh    hafizh@google.com  ...       1      6    82
# 0       RK20202344     Nina       nina@gmail.com  ...       1      6    80
# ..             ...      ...                  ...  ...     ...    ...   ...
# 7       RK20202351     Yuni      yuni@google.com  ...       0      1    87
# 5       RK20202349    Bagus    bagus@hotmail.com  ...       1      1    84
# 2       RK20202346    Prima      prima@ymail.com  ...       1      1    55
# 92      RK20202436  Munaroh  munaroh@hotmail.com  ...       0      1    91
# 82      RK20202426      Een     een@facebook.com  ...       1      1    74
#
# [100 rows x 10 columns]

# %% [markdown]
# # Mengurutkan berdasarkan 2 Column dalam 1 variabel

# %%
df_dataset.sort_values(['age',"city"], ascending=True)
# Out:
#    registration_id     name                email  ...  active  class score
# 82      RK20202426      Een     een@facebook.com  ...       1      1    74
# 92      RK20202436  Munaroh  munaroh@hotmail.com  ...       0      1    91
# 2       RK20202346    Prima      prima@ymail.com  ...       1      1    55
# 5       RK20202349    Bagus    bagus@hotmail.com  ...       1      1    84
# 7       RK20202351     Yuni      yuni@google.com  ...       0      1    87
# ..             ...      ...                  ...  ...     ...    ...   ...
# 66      RK20202410    Rizki      rizki@gmail.com  ...       0      6    67
# 32      RK20202376   Hafizh    hafizh@google.com  ...       1      6    82
# 42      RK20202386   Hendra   hendra@hotmail.com  ...       1      6    75
# 3       RK20202347   Firman    firman@google.com  ...       1      6    93
# 13      RK20202357   Amelia     amelia@ymail.com  ...       1      6    67
#
# [100 rows x 10 columns]

# %% [markdown]
# ### Ambil data 10 orang pertama sesuai abjad

# %%
Top_10_New_Account = df_dataset.sort_values('name', ascending=True)
Top_10_New_Account.head(10)

# bisa gini, bikin variabel baru atau (yg dibawah baris ini)

df_dataset.sort_values(['name'], ascending=True).head(10)
# Out:
#    registration_id      name                 email  ...  active  class score
# 95      RK20202439     Abdul       abdul@gmail.com  ...       0      6    59
# 57      RK20202401     Abdul     abdul@samsung.com  ...       1      2    81
# 75      RK20202419    Achmad      achmad@ymail.com  ...       1      5    53
# 79      RK20202423       Ade         ade@gmail.com  ...       0      6    74
# 84      RK20202428       Adi         adi@gmail.com  ...       0      4    91
# 69      RK20202413    Aditya      aditya@gmail.com  ...       1      5    59
# 64      RK20202408  Agustina  agustina@samsung.com  ...       1      2    59
# 11      RK20202355    Amalia    amalia@hotmail.com  ...       1      6    63
# 13      RK20202357    Amelia      amelia@ymail.com  ...       1      6    67
# 71      RK20202415     Angga       angga@ymail.com  ...       1      6    71
#
# [10 rows x 10 columns]

# %% [markdown]
# ### [CHALLENGE] Ambil data 10 orang dengan score terendah

# %%
df_dataset.sort_values('score', ascending=True).head(10)
# Out:
#    registration_id      name                 email  ...  active  class score
# 81      RK20202425     Aulia       aulia@ymail.com  ...       1      6    50
# 89      RK20202433      Tuti       tuti@google.com  ...       1      5    51
# 99      RK20202443     Ilham       ilham@gmail.com  ...       1      2    52
# 48      RK20202392    Dudung   dudung@facebook.com  ...       1      4    53
# 75      RK20202419    Achmad      achmad@ymail.com  ...       1      5    53
# 2       RK20202346     Prima       prima@ymail.com  ...       1      1    55
# 91      RK20202435  Setiawan  setiawan@samsung.com  ...       0      5    55
# 37      RK20202381     Retno       retno@gmail.com  ...       1      6    57
# 25      RK20202369     Endah     endah@rakamin.com  ...       1      6    58
# 96      RK20202440       Ria         ria@gmail.com  ...       0      6    58
#
# [10 rows x 10 columns]

# %% [markdown]
# # Data Filtering, Phyton Case Sesitive

# %% [markdown]
# ### Filter kolom name, email, phone, province -> Mirip Seperti Select di SQL

# %%
df_dataset[ ['name','email','phone','province'] ].head()
# Out:
#      name              email      phone        province
# 0    Nina     nina@gmail.com  628198157  Kepulauan Riau
# 1    Dyah     dyah@gmail.com  628306496      Jawa Barat
# 2   Prima    prima@ymail.com  628755450         Jakarta
# 3  Firman  firman@google.com  628638112         Lampung
# 4     Eva    eva@rakamin.com  628702735      Jawa Timur

# %% [markdown]
# ## Ambil nama tiap orang beserta score nya

# %%
df_dataset[['name','score']]
# Out:
#       name  score
# 0     Nina     80
# 1     Dyah     66
# 2    Prima     55
# 3   Firman     93
# 4      Eva     80
# ..     ...    ...
# 95   Abdul     59
# 96     Ria     58
# 97   Putra     71
# 98   Kokom     73
# 99   Ilham     52
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Ambil data orang-orang dari Jakarta - > Sama seperti Where di SQL

# %%
df_dataset[df_dataset['province']=='Jakarta']
# Out:
#    registration_id     name                 email  ...  active  class score
# 2       RK20202346    Prima       prima@ymail.com  ...       1      1    55
# 5       RK20202349    Bagus     bagus@hotmail.com  ...       1      1    84
# 7       RK20202351     Yuni       yuni@google.com  ...       0      1    87
# 9       RK20202353    Nurul       nurul@gmail.com  ...       0      1    79
# 15      RK20202359    Dadan    dadan@facebook.com  ...       1      1    63
# 16      RK20202360    Diana       diana@ymail.com  ...       0      1    87
# 31      RK20202375    Ratih       ratih@gmail.com  ...       0      1    81
# 40      RK20202384    Raden     raden@rakamin.com  ...       1      1    87
# 46      RK20202390    Wulan  wulan@rocketmail.com  ...       1      1    73
# 67      RK20202411  Hidayat   hidayat@hotmail.com  ...       0      1   100
# 82      RK20202426      Een      een@facebook.com  ...       1      1    74
# ...

# %% [markdown]
# ### Ambil data orang-orang yang berusia lebih dari 30 tahun

# %%
df_dataset[df_dataset['age'] > 30]
# Out:
#    registration_id    name               email  ...  active  class score
# 0       RK20202344    Nina      nina@gmail.com  ...       1      6    80
# 3       RK20202347  Firman   firman@google.com  ...       1      6    93
# 4       RK20202348     Eva     eva@rakamin.com  ...       0      5    80
# 6       RK20202350   Citra   citra@hotmail.com  ...       1      4    69
# 8       RK20202352    Putu      putu@gmail.com  ...       1      5    69
# ..             ...     ...                 ...  ...     ...    ...   ...
# 93      RK20202437   Yunus  yunus@facebook.com  ...       0      6    66
# 94      RK20202438    Arif      arif@gmail.com  ...       0      6    95
# 95      RK20202439   Abdul     abdul@gmail.com  ...       0      6    59
# 96      RK20202440     Ria       ria@gmail.com  ...       0      6    58
# 97      RK20202441   Putra     putra@gmail.com  ...       1      6    71
#
# [65 rows x 10 columns]

# %% [markdown]
# ### Ambil data orang-orang dengan score <= 60

# %%
df_dataset[df_dataset['score'] <= 60]
# Out:
#    registration_id      name                 email  ...  active  class score
# 2       RK20202346     Prima       prima@ymail.com  ...       1      1    55
# 23      RK20202367    Rahayu      rahayu@gmail.com  ...       1      2    60
# 25      RK20202369     Endah     endah@rakamin.com  ...       1      6    58
# 29      RK20202373      Devi      devi@hotmail.com  ...       1      4    60
# 37      RK20202381     Retno       retno@gmail.com  ...       1      6    57
# 38      RK20202382   Kartika     kartika@gmail.com  ...       0      2    59
# 41      RK20202385     Indra       indra@gmail.com  ...       1      4    60
# 48      RK20202392    Dudung   dudung@facebook.com  ...       1      4    53
# 51      RK20202395     Arief     arief@hotmail.com  ...       1      5    60
# 64      RK20202408  Agustina  agustina@samsung.com  ...       1      2    59
# 69      RK20202413    Aditya      aditya@gmail.com  ...       1      5    59
# ...

# %% [markdown]
# ## Ada berapa orang yang punya score <= 60

# %%
df_dataset[df_dataset['score'] <= 60].shape[0]
# jawabbannya 19
# Out:
# 19

# %% [markdown]
# ### Ambil data orang-orang yang bukan dari kota Depok -  Tidaksama dengan !=

# %%
df_dataset[df_dataset['city'] != 'Depok']
# Out:
#    registration_id    name               email  ...  active  class score
# 0       RK20202344    Nina      nina@gmail.com  ...       1      6    80
# 1       RK20202345    Dyah      dyah@gmail.com  ...       0      2    66
# 2       RK20202346   Prima     prima@ymail.com  ...       1      1    55
# 3       RK20202347  Firman   firman@google.com  ...       1      6    93
# 4       RK20202348     Eva     eva@rakamin.com  ...       0      5    80
# ..             ...     ...                 ...  ...     ...    ...   ...
# 95      RK20202439   Abdul     abdul@gmail.com  ...       0      6    59
# 96      RK20202440     Ria       ria@gmail.com  ...       0      6    58
# 97      RK20202441   Putra     putra@gmail.com  ...       1      6    71
# 98      RK20202442   Kokom  kokom@facebook.com  ...       0      2    73
# 99      RK20202443   Ilham     ilham@gmail.com  ...       1      2    52
#
# [95 rows x 10 columns]

# %% [markdown]
# ## Ambil data orang-orang dari Jawa Timur dengan umur > 40, Ini juga seperti kondisi Where di SQL (Logic and & jadi kondisi keduanya harus terpenuhi

# %%
df_dataset[ (df_dataset['province'] == 'Jawa Timur') & (df_dataset['age'] > 40) ]
# Out:
#    registration_id       name                     email  ...  active  class score
# 4       RK20202348        Eva           eva@rakamin.com  ...       0      5    80
# 8       RK20202352       Putu            putu@gmail.com  ...       1      5    69
# 33      RK20202377      Rizky         rizky@samsung.com  ...       1      5    74
# 45      RK20202389        Ari             ari@gmail.com  ...       1      5    82
# 51      RK20202395      Arief         arief@hotmail.com  ...       1      5    60
# 61      RK20202405       Rini          rini@samsung.com  ...       0      5    72
# 63      RK20202407    Wahyuni       wahyuni@samsung.com  ...       1      5    63
# 75      RK20202419     Achmad          achmad@ymail.com  ...       1      5    53
# 85      RK20202429  Anggraini  anggraini@rocketmail.com  ...       0      5    94
# 89      RK20202433       Tuti           tuti@google.com  ...       1      5    51
#
# [10 rows x 10 columns]

# %% [markdown]
# ## Ambil data orang-orang yang dari Surabaya, atau punya score > 90, Logic or, jadi salah satu kondisi aja terpenuhi dia tamilkan

# %%
df_dataset[ (df_dataset['city'] == 'Surabaya') | (df_dataset['score'] > 90) ]
# Out:
#    registration_id       name                     email  ...  active  class score
# 3       RK20202347     Firman         firman@google.com  ...       1      6    93
# 17      RK20202361  Rahmawati       rahmawati@gmail.com  ...       1      4   100
# 22      RK20202366      Deden          deden@google.com  ...       1      2    91
# 24      RK20202368  Handayani       handayani@gmail.com  ...       0      2    95
# 43      RK20202387      Intan           intan@gmail.com  ...       0      4    98
# 54      RK20202398     Lukman       lukman@facebook.com  ...       0      5    95
# 56      RK20202400       Dina          dina@hotmail.com  ...       1      2    99
# 58      RK20202402       Hadi            hadi@ymail.com  ...       1      2    97
# 59      RK20202403    Muhamad         muhamad@gmail.com  ...       0      5   100
# 61      RK20202405       Rini          rini@samsung.com  ...       0      5    72
# ...

# %% [markdown]
# ## Ambil data orang-orang yang bukan dari Malang

# %%
df_dataset[df_dataset['province']!='Malang']
# Out:
#    registration_id    name               email  ...  active  class score
# 0       RK20202344    Nina      nina@gmail.com  ...       1      6    80
# 1       RK20202345    Dyah      dyah@gmail.com  ...       0      2    66
# 2       RK20202346   Prima     prima@ymail.com  ...       1      1    55
# 3       RK20202347  Firman   firman@google.com  ...       1      6    93
# 4       RK20202348     Eva     eva@rakamin.com  ...       0      5    80
# ..             ...     ...                 ...  ...     ...    ...   ...
# 95      RK20202439   Abdul     abdul@gmail.com  ...       0      6    59
# 96      RK20202440     Ria       ria@gmail.com  ...       0      6    58
# 97      RK20202441   Putra     putra@gmail.com  ...       1      6    71
# 98      RK20202442   Kokom  kokom@facebook.com  ...       0      2    73
# 99      RK20202443   Ilham     ilham@gmail.com  ...       1      2    52
#
# [100 rows x 10 columns]

# %% [markdown]
# ## Siapa orang paling tua yang berasal dari Jawa Tengah?

# %%
Umur_Jateng = df_dataset[df_dataset['province']=='Jawa Tengah'].head(1).sort_values('age', ascending=False)
"Orang yang paling tua di Jawa Tengah adalah "+Umur_Jateng[['name']]
# Out:
#                                                 name
# 6  Orang yang paling tua di Jawa Tengah adalah Citra

# %% [markdown]
# ## [CHALLENGE] Ada berapa banyak orang di kelas 4 yang berasal dari Jawa Tengah?

# %%
kelas_4_Jateng = df_dataset[ (df_dataset['province'] == 'Jawa Tengah') & (df_dataset['class'] == 4) ]
kelas_4_Jateng.shape[0]
# Out:
# 14

# %% [markdown]
# ## [CHALLENGE] Siapa nama pemilik no HP 628833542?

# %%
pemilik = df_dataset[df_dataset['phone'] == 628833542]
"Pemiik nomor HP 628833542 adalah "+pemilik[['name']]
# Out:
#                                           name
# 65  Pemiik nomor HP 628833542 adalah Wulandari

# %% [markdown]
# ## Untuk semua orang di kelas 1, tunjukkan info nama, kota, dan provinsi nya

# %%
kelas_1 = df_dataset[df_dataset['class'] == 1]
kelas_1[['name','city','province']]
# Out:
#        name                               city province
# 2     Prima    Kota Administrasi Jakarta Pusat  Jakarta
# 5     Bagus    Kota Administrasi Jakarta Pusat  Jakarta
# 7      Yuni    Kota Administrasi Jakarta Pusat  Jakarta
# 9     Nurul  Kota Administrasi Jakarta Selatan  Jakarta
# 15    Dadan    Kota Administrasi Jakarta Utara  Jakarta
# 16    Diana    Kota Administrasi Jakarta Timur  Jakarta
# 31    Ratih    Kota Administrasi Jakarta Utara  Jakarta
# 40    Raden  Kota Administrasi Jakarta Selatan  Jakarta
# 46    Wulan    Kota Administrasi Jakarta Utara  Jakarta
# 67  Hidayat  Kota Administrasi Jakarta Selatan  Jakarta
# 82      Een    Kota Administrasi Jakarta Barat  Jakarta
# 92  Munaroh    Kota Administrasi Jakarta Barat  Jakarta

# %% [markdown]
# # Data Aggregation - > Seperti Pivot di Exell

# %% [markdown]
# ## Melihat jumlah orang per provinsi

# %%
df_dataset.groupby('province')['registration_id'].count()
# Out:
# province
# Jakarta               12
# Jambi                  2
# Jawa Barat            21
# Jawa Tengah           14
# Jawa Timur            17
# Kalimantan Barat       3
# Kalimantan Selatan     6
# Kalimantan Tengah      3
# Kalimantan Timur       8
# Kalimantan Utara       1
# Kepulauan Riau         9
# Lampung                4
# Name: registration_id, dtype: int64

# %% [markdown]
# Tambahkan .reset_index() untuk membuat dataframe yang kolomnya rata

# %%
df_dataset.groupby('province')['registration_id'].count().reset_index()
# Out:
#               province  registration_id
# 0              Jakarta               12
# 1                Jambi                2
# 2           Jawa Barat               21
# 3          Jawa Tengah               14
# 4           Jawa Timur               17
# 5     Kalimantan Barat                3
# 6   Kalimantan Selatan                6
# 7    Kalimantan Tengah                3
# 8     Kalimantan Timur                8
# 9     Kalimantan Utara                1
# 10      Kepulauan Riau                9
# 11             Lampung                4

# %% [markdown]
# ## Melihat rata-rata score tiap kelas

# %%
df_dataset.groupby('class')['score'].mean().reset_index()
# Out:
#    class      score
# 0      1  80.083333
# 1      2  75.571429
# 2      4  76.619048
# 3      5  72.473684
# 4      6  71.962963

# %% [markdown]
# diurutkan dari rata-rata score tertinggi

# %%
df_dataset.groupby('class')['score'].mean().reset_index().sort_values('score',ascending=False)
# Out:
#    class      score
# 0      1  80.083333
# 2      4  76.619048
# 1      2  75.571429
# 3      5  72.473684
# 4      6  71.962963

# %% [markdown]
# ## Untuk orang-orang dari Jakarta, berapa rata-rata score per kota?

# %%
filter = df_dataset['province'] == 'Jakarta'
Mean_Jkt = df_dataset[filter].groupby("city")['score'].mean().reset_index()
Mean_Jkt
# Out:
#                                 city      score
# 0    Kota Administrasi Jakarta Barat  82.500000
# 1    Kota Administrasi Jakarta Pusat  75.333333
# 2  Kota Administrasi Jakarta Selatan  88.666667
# 3    Kota Administrasi Jakarta Timur  87.000000
# 4    Kota Administrasi Jakarta Utara  72.333333

# %% [markdown]
# ## Berapa banyak orang yang aktif, dan tidak aktif?

# %%
filter = df_dataset['active'] == 0
df_dataset[filter].groupby('active')['registration_id'].count().reset_index()
# Out:
#    active  registration_id
# 0       0               36

# %%
filter = df_dataset['active'] == 1
df_dataset[filter].groupby('active')['registration_id'].count().reset_index()
# Out:
#    active  registration_id
# 0       1               64

# %% [markdown]
# # Filter out columns of our interest
# df_1 = df.loc[:, ["Quantity", "Unit price"]]
#
# # We have already binned the quantity data into 0 and 1's for counting.
# # So we don't need any pre-processing
#
# # Group the data
# groupby = df_1.groupby("Quantity", axis=0)
#
# # Apply the function(here mean)
# groupby.mean()
